# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import xlrd
# %matplotlib inline

import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
# !pip install xlrd
# !pip install openpyxl
# Out:
# Requirement already satisfied: xlrd in c:\users\ajay\appdata\local\programs\python\python311\lib\site-packages (2.0.1)
# Requirement already satisfied: openpyxl in c:\users\ajay\appdata\local\programs\python\python311\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\ajay\appdata\local\programs\python\python311\lib\site-packages (from openpyxl) (1.1.0)

# %%
# !python.exe -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\ajay\appdata\local\programs\python\python311\lib\site-packages (24.1.1)

# %%
transaction_data= pd.read_excel("C:\\Users\\AJAY\\QVI_transaction_data.xlsx")
transaction_data
# Out:
#          DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0       43390          1            1000       1         5
# 1       43599          1            1307     348        66
# 2       43605          1            1343     383        61
# 3       43329          2            2373     974        69
# 4       43330          2            2426    1038       108
# ...       ...        ...             ...     ...       ...
# 264831  43533        272          272319  270088        89
# 264832  43325        272          272358  270154        74
# 264833  43410        272          272379  270187        51
# 264834  43461        272          272379  270188        42
# 264835  43365        272          272380  270189        74
#
#                                        PROD_NAME  PROD_QTY  TOT_SALES
# 0         Natural Chip        Compny SeaSalt175g         2        6.0
# 1                       CCs Nacho Cheese    175g         3        6.3
# 2         Smiths Crinkle Cut  Chips Chicken 170g         2        2.9
# 3         Smiths Chip Thinly  S/Cream&Onion 175g         5       15.0
# 4       Kettle Tortilla ChpsHny&Jlpno Chili 150g         3       13.8
# ...                                          ...       ...        ...
# 264831   Kettle Sweet Chilli And Sour Cream 175g         2       10.8
# 264832             Tostitos Splash Of  Lime 175g         1        4.4
# 264833                  Doritos Mexicana    170g         2        8.8
# 264834   Doritos Corn Chip Mexican Jalapeno 150g         2        7.8
# 264835             Tostitos Splash Of  Lime 175g         2        8.8
#
# [264836 rows x 8 columns]

# %%
transaction_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264836 entries, 0 to 264835
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DATE            264836 non-null  int64
#  1   STORE_NBR       264836 non-null  int64
#  2   LYLTY_CARD_NBR  264836 non-null  int64
#  3   TXN_ID          264836 non-null  int64
#  4   PROD_NBR        264836 non-null  int64
#  5   PROD_NAME       264836 non-null  object
#  6   PROD_QTY        264836 non-null  int64
#  7   TOT_SALES       264836 non-null  float64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 16.2+ MB

# %%
transaction_data.isnull().sum()
# Out:
# DATE              0
# STORE_NBR         0
# LYLTY_CARD_NBR    0
# TXN_ID            0
# PROD_NBR          0
# PROD_NAME         0
# PROD_QTY          0
# TOT_SALES         0
# dtype: int64

# %%
figure, axis=plt.subplots(1, 2, figsize=(15, 5))
axis[0].boxplot(transaction_data["PROD_QTY"])
axis[1].boxplot(transaction_data["TOT_SALES"])
axis[0].set_title("PROD_QTY")
axis[1].set_title("TOT_SALES")
plt.show()

# %%
transaction_data=transaction_data[transaction_data["PROD_QTY"]<100]
transaction_data=transaction_data[transaction_data["TOT_SALES"]<500]
transaction_data=transaction_data.reset_index(drop=True)    #   Resetting the index of the pandas.DataFrame.
transaction_data
# Out:
#          DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0       43390          1            1000       1         5
# 1       43599          1            1307     348        66
# 2       43605          1            1343     383        61
# 3       43329          2            2373     974        69
# 4       43330          2            2426    1038       108
# ...       ...        ...             ...     ...       ...
# 264829  43533        272          272319  270088        89
# 264830  43325        272          272358  270154        74
# 264831  43410        272          272379  270187        51
# 264832  43461        272          272379  270188        42
# 264833  43365        272          272380  270189        74
#
#                                        PROD_NAME  PROD_QTY  TOT_SALES
# 0         Natural Chip        Compny SeaSalt175g         2        6.0
# 1                       CCs Nacho Cheese    175g         3        6.3
# 2         Smiths Crinkle Cut  Chips Chicken 170g         2        2.9
# 3         Smiths Chip Thinly  S/Cream&Onion 175g         5       15.0
# 4       Kettle Tortilla ChpsHny&Jlpno Chili 150g         3       13.8
# ...                                          ...       ...        ...
# 264829   Kettle Sweet Chilli And Sour Cream 175g         2       10.8
# 264830             Tostitos Splash Of  Lime 175g         1        4.4
# 264831                  Doritos Mexicana    170g         2        8.8
# 264832   Doritos Corn Chip Mexican Jalapeno 150g         2        7.8
# 264833             Tostitos Splash Of  Lime 175g         2        8.8
#
# [264834 rows x 8 columns]

# %%
date=transaction_data["DATE"].tolist()
for i in range(len(date)):
    date[i]=xlrd.xldate_as_datetime(date[i],0)
    
transaction_data["DATE"]=date
transaction_data
# Out:
#              DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0      2018-10-17          1            1000       1         5
# 1      2019-05-14          1            1307     348        66
# 2      2019-05-20          1            1343     383        61
# 3      2018-08-17          2            2373     974        69
# 4      2018-08-18          2            2426    1038       108
# ...           ...        ...             ...     ...       ...
# 264829 2019-03-09        272          272319  270088        89
# 264830 2018-08-13        272          272358  270154        74
# 264831 2018-11-06        272          272379  270187        51
# 264832 2018-12-27        272          272379  270188        42
# 264833 2018-09-22        272          272380  270189        74
#
#                                        PROD_NAME  PROD_QTY  TOT_SALES  \
# 0         Natural Chip        Compny SeaSalt175g         2        6.0
# 1                       CCs Nacho Cheese    175g         3        6.3
# 2         Smiths Crinkle Cut  Chips Chicken 170g         2        2.9
# 3         Smiths Chip Thinly  S/Cream&Onion 175g         5       15.0
# 4       Kettle Tortilla ChpsHny&Jlpno Chili 150g         3       13.8
# ...                                          ...       ...        ...
# 264829   Kettle Sweet Chilli And Sour Cream 175g         2       10.8
# 264830             Tostitos Splash Of  Lime 175g         1        4.4
# 264831                  Doritos Mexicana    170g         2        8.8
# 264832   Doritos Corn Chip Mexican Jalapeno 150g         2        7.8
# 264833             Tostitos Splash Of  Lime 175g         2        8.8
#
#              Date
# 0      2018-10-17
# 1      2019-05-14
# 2      2019-05-20
# 3      2018-08-17
# 4      2018-08-18
# ...           ...
# 264829 2019-03-09
# 264830 2018-08-13
# 264831 2018-11-06
# 264832 2018-12-27
# 264833 2018-09-22
#
# [264834 rows x 9 columns]

# %%
# Out:
#          DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0       43390          1            1000       1         5
# 1       43599          1            1307     348        66
# 2       43605          1            1343     383        61
# 3       43329          2            2373     974        69
# 4       43330          2            2426    1038       108
# ...       ...        ...             ...     ...       ...
# 264829  43533        272          272319  270088        89
# 264830  43325        272          272358  270154        74
# 264831  43410        272          272379  270187        51
# 264832  43461        272          272379  270188        42
# 264833  43365        272          272380  270189        74
#
#                                        PROD_NAME  PROD_QTY  TOT_SALES  \
# 0         Natural Chip        Compny SeaSalt175g         2        6.0
# 1                       CCs Nacho Cheese    175g         3        6.3
# 2         Smiths Crinkle Cut  Chips Chicken 170g         2        2.9
# 3         Smiths Chip Thinly  S/Cream&Onion 175g         5       15.0
# 4       Kettle Tortilla ChpsHny&Jlpno Chili 150g         3       13.8
# ...                                          ...       ...        ...
# 264829   Kettle Sweet Chilli And Sour Cream 175g         2       10.8
# 264830             Tostitos Splash Of  Lime 175g         1        4.4
# 264831                  Doritos Mexicana    170g         2        8.8
# 264832   Doritos Corn Chip Mexican Jalapeno 150g         2        7.8
# 264833             Tostitos Splash Of  Lime 175g         2        8.8
#
#              Date
# 0      2018-10-17
# 1      2019-05-14
# 2      2019-05-20
# 3      2018-08-17
# 4      2018-08-18
# ...           ...
# 264829 2019-03-09
# 264830 2018-08-13
# 264831 2018-11-06
# 264832 2018-12-27
# 264833 2018-09-22
#
# [264834 rows x 9 columns]

# %%
purchase_behaviour=pd.read_csv("QVI_purchase_behaviour.csv")   
purchase_behaviour
# Out:
#        LYLTY_CARD_NBR               LIFESTAGE PREMIUM_CUSTOMER
# 0                1000   YOUNG SINGLES/COUPLES          Premium
# 1                1002   YOUNG SINGLES/COUPLES       Mainstream
# 2                1003          YOUNG FAMILIES           Budget
# 3                1004   OLDER SINGLES/COUPLES       Mainstream
# 4                1005  MIDAGE SINGLES/COUPLES       Mainstream
# ...               ...                     ...              ...
# 72632         2370651  MIDAGE SINGLES/COUPLES       Mainstream
# 72633         2370701          YOUNG FAMILIES       Mainstream
# 72634         2370751          YOUNG FAMILIES          Premium
# 72635         2370961          OLDER FAMILIES           Budget
# 72636         2373711   YOUNG SINGLES/COUPLES       Mainstream
#
# [72637 rows x 3 columns]

# %%
purchase_behaviour.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72637 entries, 0 to 72636
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LYLTY_CARD_NBR    72637 non-null  int64
#  1   LIFESTAGE         72637 non-null  object
#  2   PREMIUM_CUSTOMER  72637 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.7+ MB

# %%
dataframe=pd.merge(transaction_data, purchase_behaviour, on="LYLTY_CARD_NBR")
dataframe
# Out:
#              DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0      2018-10-17          1            1000       1         5
# 1      2019-05-14          1            1307     348        66
# 2      2018-11-10          1            1307     346        96
# 3      2019-03-09          1            1307     347        54
# 4      2019-05-20          1            1343     383        61
# ...           ...        ...             ...     ...       ...
# 264829 2019-03-09        272          272319  270088        89
# 264830 2018-08-13        272          272358  270154        74
# 264831 2018-11-06        272          272379  270187        51
# 264832 2018-12-27        272          272379  270188        42
# 264833 2018-09-22        272          272380  270189        74
#
#                                       PROD_NAME  PROD_QTY  TOT_SALES  \
# 0        Natural Chip        Compny SeaSalt175g         2        6.0
# 1                      CCs Nacho Cheese    175g         3        6.3
# 2                WW Original Stacked Chips 160g         2        3.8
# 3                             CCs Original 175g         1        2.1
# 4        Smiths Crinkle Cut  Chips Chicken 170g         2        2.9
# ...                                         ...       ...        ...
# 264829  Kettle Sweet Chilli And Sour Cream 175g         2       10.8
# 264830            Tostitos Splash Of  Lime 175g         1        4.4
# 264831                 Doritos Mexicana    170g         2        8.8
# 264832  Doritos Corn Chip Mexican Jalapeno 150g         2        7.8
# 264833            Tostitos Splash Of  Lime 175g         2        8.8
#
#              Date               LIFESTAGE PREMIUM_CUSTOMER
# 0      2018-10-17   YOUNG SINGLES/COUPLES          Premium
# 1      2019-05-14  MIDAGE SINGLES/COUPLES           Budget
# 2      2018-11-10  MIDAGE SINGLES/COUPLES           Budget
# 3      2019-03-09  MIDAGE SINGLES/COUPLES           Budget
# 4      2019-05-20  MIDAGE SINGLES/COUPLES           Budget
# ...           ...                     ...              ...
# 264829 2019-03-09   YOUNG SINGLES/COUPLES          Premium
# 264830 2018-08-13   YOUNG SINGLES/COUPLES          Premium
# 264831 2018-11-06   YOUNG SINGLES/COUPLES          Premium
# 264832 2018-12-27   YOUNG SINGLES/COUPLES          Premium
# 264833 2018-09-22   YOUNG SINGLES/COUPLES          Premium
#
# [264834 rows x 11 columns]

# %%
unique_products=list(dataframe["PROD_NAME"].unique())
print("Total Distinct Products:", len(unique_products))
# Out:
# Total Distinct Products: 114

# %%
dataframe["PROD_NAME_CLEAN"]=dataframe["PROD_NAME"].str.replace('\d+g','')
dataframe["PROD_SIZE"]=dataframe["PROD_NAME"].str.extract("(\d+)")
dataframe["PROD_NAME"]=dataframe["PROD_NAME_CLEAN"]
dataframe=dataframe.drop("PROD_NAME_CLEAN",axis=1)
dataframe["BRAND_NAME"]=dataframe["PROD_NAME"].str.split().str[0]
dataframe=dataframe.loc[:, ["DATE", "STORE_NBR", "LYLTY_CARD_NBR", "TXN_ID", "PROD_NBR", "PROD_NAME", "PROD_SIZE", "BRAND_NAME", "PROD_QTY", "TOT_SALES", "LIFESTAGE", "PREMIUM_CUSTOMER"]]   
dataframe
# Out:
#          DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0       43390          1            1000       1         5
# 1       43599          1            1307     348        66
# 2       43414          1            1307     346        96
# 3       43533          1            1307     347        54
# 4       43605          1            1343     383        61
# ...       ...        ...             ...     ...       ...
# 264829  43533        272          272319  270088        89
# 264830  43325        272          272358  270154        74
# 264831  43410        272          272379  270187        51
# 264832  43461        272          272379  270188        42
# 264833  43365        272          272380  270189        74
#
#                                   PROD_NAME PROD_SIZE BRAND_NAME  PROD_QTY  \
# 0        Natural Chip        Compny SeaSalt       175    Natural         2
# 1                      CCs Nacho Cheese           175        CCs         3
# 2                WW Original Stacked Chips        160         WW         2
# 3                             CCs Original        175        CCs         1
# 4        Smiths Crinkle Cut  Chips Chicken        170     Smiths         2
# ...                                     ...       ...        ...       ...
# 264829  Kettle Sweet Chilli And Sour Cream        175     Kettle         2
# 264830            Tostitos Splash Of  Lime        175   Tostitos         1
# 264831                 Doritos Mexicana           170    Doritos         2
# 264832  Doritos Corn Chip Mexican Jalapeno        150    Doritos         2
# 264833            Tostitos Splash Of  Lime        175   Tostitos         2
#
#         TOT_SALES               LIFESTAGE PREMIUM_CUSTOMER
# 0             6.0   YOUNG SINGLES/COUPLES          Premium
# 1             6.3  MIDAGE SINGLES/COUPLES           Budget
# 2             3.8  MIDAGE SINGLES/COUPLES           Budget
# 3             2.1  MIDAGE SINGLES/COUPLES           Budget
# 4             2.9  MIDAGE SINGLES/COUPLES           Budget
# ...           ...                     ...              ...
# 264829       10.8   YOUNG SINGLES/COUPLES          Premium
# 264830        4.4   YOUNG SINGLES/COUPLES          Premium
# 264831        8.8   YOUNG SINGLES/COUPLES          Premium
# 264832        7.8   YOUNG SINGLES/COUPLES          Premium
# 264833        8.8   YOUNG SINGLES/COUPLES          Premium
#
# [264834 rows x 12 columns]

# %%
dataframe=dataframe.sort_values(by="DATE")
dataframe=dataframe.reset_index(drop=True)
dataframe
# Out:
#              DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0      2018-07-01         27           27181   24218        70
# 1      2018-07-01        191          191099  192367       103
# 2      2018-07-01        257          257010  255769        24
# 3      2018-07-01         48           48129   43842       114
# 4      2018-07-01        203          203013  202339        23
# ...           ...        ...             ...     ...       ...
# 264829 2019-06-30         67           67129   64592        57
# 264830 2019-06-30        133          133121  136776        44
# 264831 2019-06-30        257          257195  256935        83
# 264832 2019-06-30         45           45057   40739        91
# 264833 2019-06-30        199          199122  198088        42
#
#                                        PROD_NAME  PROD_QTY  TOT_SALES  \
# 0        Tyrrells Crisps     Lightly Salted 165g         2        8.4
# 1           RRD Steak &         Chimuchurri 150g         2        5.4
# 2          Grain Waves         Sweet Chilli 210g         2        7.2
# 3          Kettle Sensations   Siracha Lime 150g         2        9.2
# 4                           Cheezels Cheese 330g         2       11.4
# ...                                          ...       ...        ...
# 264829  Old El Paso Salsa   Dip Tomato Mild 300g         2       10.2
# 264830            Thins Chips Light&  Tangy 175g         2        6.6
# 264831         WW D/Style Chip     Sea Salt 200g         2        3.8
# 264832                  CCs Tasty Cheese    175g         2        4.2
# 264833   Doritos Corn Chip Mexican Jalapeno 150g         2        7.8
#
#              Date               LIFESTAGE PREMIUM_CUSTOMER
# 0      2018-07-01                RETIREES           Budget
# 1      2018-07-01          YOUNG FAMILIES           Budget
# 2      2018-07-01          YOUNG FAMILIES          Premium
# 3      2018-07-01          OLDER FAMILIES       Mainstream
# 4      2018-07-01  MIDAGE SINGLES/COUPLES           Budget
# ...           ...                     ...              ...
# 264829 2019-06-30   OLDER SINGLES/COUPLES       Mainstream
# 264830 2019-06-30          OLDER FAMILIES       Mainstream
# 264831 2019-06-30          YOUNG FAMILIES       Mainstream
# 264832 2019-06-30   OLDER SINGLES/COUPLES          Premium
# 264833 2019-06-30            NEW FAMILIES          Premium
#
# [264834 rows x 11 columns]

# %%
pd.date_range(start="2018-07-01", end="2019-06-30").difference(dataframe["DATE"])
# Out:
# DatetimeIndex(['2018-12-25'], dtype='datetime64[ns]', freq=None)

# %%
dataframe=dataframe.append({"DATE": pd.to_datetime("2018-12-25"), "STORE_NBR": 0, "LYLTY_CARD_NBR": 0, "TXN_ID": 0, "PROD_NBR": 0, "PROD_NAME": "None", "BRAND_NAME": "None", "PROD_SIZE": "0g", "PROD_QTY": 0, "TOT_SALES": 0, "LIFESTAGE": "None", "PREMIUM_CUSTOMER": "None"}, ignore_index=True)
dataframe=dataframe.sort_values(by="DATE")
datafrme
